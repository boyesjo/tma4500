# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
nn = pd.read_csv("test_nn2.csv").to_numpy().T
qnn = pd.read_csv("test_qnn.csv").to_numpy().T
qnn_noisy = pd.read_csv("test_qnn_noisy.csv").to_numpy().T

# %%
plt.plot(nn.mean(axis=1), label="NN", color="blue")
plt.plot(qnn.mean(axis=1), label="QNN", color="red")
plt.plot(qnn_noisy.mean(axis=1), label="QNN noisy", color="green")
plt.legend()
